# %%
#!/usr/bin/env python

'''
DESCRIPTION
-----------
    To export pathway order
    
RETURN
------
    {}. :  file
        
        
EXPORTED FILE(s) LOCATION
-------------------------
    .//{}/{EXPERIMENT}/{}.
'''

# importing default libraries
# import os, argparse, sys
# sys.path.append('./')
import os, sys
ROOT_DIR = os.path.dirname(os.path.dirname(os.path.abspath('__file__')))
os.chdir(ROOT_DIR)
sys.path.append(ROOT_DIR)
import os
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "3"

# %% [raw]
# import os
# os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
# os.environ["CUDA_VISIBLE_DEVICES"] = "1,2"

# %%
# importing scripts in scripts folder
from scripts import config as src
# importing default libraries
import numpy as np
import pandas as pd
import datetime as dt
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings('ignore')

from sklearn.preprocessing import OneHotEncoder

rand_state = 91

time_start = dt.datetime.now().time().strftime('%H:%M:%S') # = time.time() dt.datetime.now().strftime('%Y%m%d_%I%M%S%p')
# Out:
# **** scripts/config.py IMPORTED!!!
# **** PROJECT FOLDER ,  /home/pgundogdu/projects/signalization_prior_knowledge_based_nn

# %%
# # giving the model path
# model_path = '../data/output/result_NN/models/signaling_log1p/design_a1_signaling.h5'

dataset              = 'immune_new.pck'
# bio_knowledge        = 'pbk_layer_hsa_sig.txt'
bio_knowledge        = 'pbk_circuit_hsa_sig.txt'
experiment           = 'exper_immune'
analysis             = 'activation'

# defining biological knowledge layer based on the architecture of required model
bio_layer_number     = 1

# the output location
loc_output = os.path.join(src.DIR_REPORTS, analysis, experiment)
src.define_folder(loc_=loc_output)
# Out:
# FOLDER information,  /home/pgundogdu/projects/signalization_prior_knowledge_based_nn/reports/activation/exper_immune/
# '/home/pgundogdu/projects/signalization_prior_knowledge_based_nn/reports/activation/exper_immune/'

# %%
df = pd.read_pickle(os.path.join(src.DIR_DATA_PROCESSED, experiment, dataset))

df_bio = pd.DataFrame(pd.read_csv(os.path.join(src.DIR_DATA_PROCESSED, bio_knowledge), index_col=0)).sort_index()

# %%
df_bio_with_df = pd.merge(left=pd.DataFrame(df.columns[:-1]).set_index(0)
                                 , right=df_bio
                                 , left_index=True
                                 , right_index=True
                                 , how='left').fillna(0.0)
df_bio_with_df
# Out:
#             P-hsa03320-62  P-hsa03320-45  P-hsa03320-43  P-hsa03320-23  \
# 0
# or4f5                 0.0            0.0            0.0            0.0
# fo538757.2            0.0            0.0            0.0            0.0
# or4f29                0.0            0.0            0.0            0.0
# or4f16                0.0            0.0            0.0            0.0
# samd11                0.0            0.0            0.0            0.0
# ...                   ...            ...            ...            ...
# ac233755.2            0.0            0.0            0.0            0.0
# ac233755.1            0.0            0.0            0.0            0.0
# ac240274.1            0.0            0.0            0.0            0.0
# ac213203.1            0.0            0.0            0.0            0.0
# fam231b               0.0            0.0            0.0            0.0
#
#             P-hsa03320-32  P-hsa03320-8  P-hsa03320-7  P-hsa03320-9  \
# 0
# or4f5                 0.0           0.0           0.0           0.0
# fo538757.2            0.0           0.0           0.0           0.0
# or4f29                0.0           0.0           0.0           0.0
# or4f16                0.0           0.0           0.0           0.0
# samd11                0.0           0.0           0.0           0.0
# ...                   ...           ...           ...           ...
# ac233755.2            0.0           0.0           0.0           0.0
# ac233755.1            0.0           0.0           0.0           0.0
# ac240274.1            0.0           0.0           0.0           0.0
# ac213203.1            0.0           0.0           0.0           0.0
# fam231b               0.0           0.0           0.0           0.0
#
#             P-hsa03320-39  P-hsa03320-38  ...  P-hsa04976-38  P-hsa04976-37  \
# 0                                         ...
# or4f5                 0.0            0.0  ...            0.0            0.0
# fo538757.2            0.0            0.0  ...            0.0            0.0
# or4f29                0.0            0.0  ...            0.0            0.0
# or4f16                0.0            0.0  ...            0.0            0.0
# samd11                0.0            0.0  ...            0.0            0.0
# ...                   ...            ...  ...            ...            ...
# ac233755.2            0.0            0.0  ...            0.0            0.0
# ac233755.1            0.0            0.0  ...            0.0            0.0
# ac240274.1            0.0            0.0  ...            0.0            0.0
# ac213203.1            0.0            0.0  ...            0.0            0.0
# fam231b               0.0            0.0  ...            0.0            0.0
#
#             P-hsa04976-36  P-hsa04976-34  P-hsa04976-41  P-hsa04976-16  \
# 0
# or4f5                 0.0            0.0            0.0            0.0
# fo538757.2            0.0            0.0            0.0            0.0
# or4f29                0.0            0.0            0.0            0.0
# or4f16                0.0            0.0            0.0            0.0
# samd11                0.0            0.0            0.0            0.0
# ...                   ...            ...            ...            ...
# ac233755.2            0.0            0.0            0.0            0.0
# ac233755.1            0.0            0.0            0.0            0.0
# ac240274.1            0.0            0.0            0.0            0.0
# ac213203.1            0.0            0.0            0.0            0.0
# fam231b               0.0            0.0            0.0            0.0
#
#             P-hsa05100-55  P-hsa05100-33  P-hsa05100-15  P-hsa05100-24
# 0
# or4f5                 0.0            0.0            0.0            0.0
# fo538757.2            0.0            0.0            0.0            0.0
# or4f29                0.0            0.0            0.0            0.0
# or4f16                0.0            0.0            0.0            0.0
# samd11                0.0            0.0            0.0            0.0
# ...                   ...            ...            ...            ...
# ac233755.2            0.0            0.0            0.0            0.0
# ac233755.1            0.0            0.0            0.0            0.0
# ac240274.1            0.0            0.0            0.0            0.0
# ac213203.1            0.0            0.0            0.0            0.0
# fam231b               0.0            0.0            0.0            0.0
#
# [19595 rows x 1210 columns]

# %%
print('Dataset cell type, ', df.groupby('cell_type').size())
print('Dataset shape                     , ', df.shape)
print('Biological knowledge shape        , ', df_bio.shape)
print('Biological knowledge with df shape, ', df_bio_with_df.shape)

print('\nDataset gene order first 10              ,', list(df.columns[:10]))
print('Biological knowledge gene order first 10, ', list(df_bio_with_df.index[:10].values))
# Out:
# Dataset cell type,  cell_type
# b     1465
# e     1747
# mo     954
# n      485
# nk     546
# sp    3742
# t      517
# dtype: int64
# Dataset shape                     ,  (9456, 19596)
# Biological knowledge shape        ,  (2987, 1210)
# Biological knowledge with df shape,  (19595, 1210)
#
# Dataset gene order first 10              , ['or4f5', 'fo538757.2', 'or4f29', 'or4f16', 'samd11', 'noc2l', 'klhl17', 'plekhn1', 'perm1', 'hes4']
# Biological knowledge gene order first 10,  ['or4f5', 'fo538757.2', 'or4f29', 'or4f16', 'samd11', 'noc2l', 'klhl17', 'plekhn1', 'perm1', 'hes4']

# %%
design_name = 'circuits'
# design_name = 'pathways'
split='train_test_split_tuningFalse_filtergeneFalse'
model_name =f'{design_name}_1_layer'
# model, model_pbk = src.loading_model(f'./models/{experiment}/{split}/design_{model_name}_immune_new_Adam_relu_0.h5', -1)
# model_pbk.summary()

# %%
SEED = 91 # for reproducible result
test_size = 0.5
train_test_repeat = 100
ohe = OneHotEncoder()
X = df.iloc[:, :-1].values
y = df.iloc[:, -1:]
y_category = df.iloc[:, -1].astype('category').cat.codes
y_ohe = ohe.fit_transform(y.values).toarray()
print(X.shape)
print(y.shape)

for i in range(0, 100):
    _, _, _, y_test = train_test_split(X, y
                                       , test_size=test_size
                                       , shuffle=True
                                       , random_state=SEED+i
                                       , stratify=y_ohe)
    test_index = y_test.index
    print(sorted(test_index)[:10], sorted(test_index)[-10:])
    model, model_pbk = src.loading_model(f'./models/{experiment}/{split}/design_{model_name}_immune_new_Adam_relu_{i}.h5', -1)
    
    y_pred = model_pbk.predict(X)
    # creating dataframe which stores both prediction label of model and 'encode' information of given layer
    df_activation_pred = pd.concat([pd.DataFrame(y_pred, columns=df_bio_with_df.columns)
                                    , pd.DataFrame([ohe.categories_[0][i] for i in np.argmax(model.predict(X), axis=-1)],  columns=['cell_type'])]
                                  , axis=1)
    df_activation_pred['split'] = ' training'
    df_activation_pred.loc[df_activation_pred.index.isin(test_index), 'split']='testing'
    
    df_activation_pred.to_csv(os.path.join(loc_output, f'activation_score_{design_name}_split_{i}.csv'), index=False)

# print(groups.shape)
# Out:
# (9456, 19595)
# (9456, 1)
# [0, 2, 4, 5, 7, 13, 19, 20, 21, 25] [9438, 9440, 9441, 9442, 9444, 9446, 9448, 9449, 9452, 9454]
# Loaded model!! ./models/exper_immune/train_test_split_tuningFalse_filtergeneFalse/design_circuits_1_layer_immune_new_Adam_relu_0.h5
# [0, 1, 4, 5, 7, 8, 10, 12, 13, 14] [9439, 9443, 9444, 9446, 9447, 9448, 9451, 9452, 9454, 9455]
# Loaded model!! ./models/exper_immune/train_test_split_tuningFalse_filtergeneFalse/design_circuits_1_layer_immune_new_Adam_relu_1.h5
# [4, 7, 8, 9, 11, 12, 14, 16, 17, 18] [9434, 9435, 9437, 9439, 9442, 9446, 9449, 9451, 9452, 9455]
# Loaded model!! ./models/exper_immune/train_test_split_tuningFalse_filtergeneFalse/design_circuits_1_layer_immune_new_Adam_relu_2.h5
# [0, 1, 2, 5, 8, 11, 12, 13, 14, 15] [9430, 9432, 9437, 9439, 9443, 9447, 9451, 9453, 9454, 9455]
# Loaded model!! ./models/exper_immune/train_test_split_tuningFalse_filtergeneFalse/design_circuits_1_layer_immune_new_Adam_relu_3.h5
# [0, 5, 7, 8, 12, 13, 14, 16, 19, 26] [9438, 9439, 9442, 9445, 9447, 9448, 9449, 9450, 9452, 9453]
# Loaded model!! ./models/exper_immune/train_test_split_tuningFalse_filtergeneFalse/design_circuits_1_layer_immune_new_Adam_relu_4.h5
# [1, 3, 4, 7, 8, 9, 13, 14, 24, 25] [9426, 9427, 9432, 9433, 9440, 9441, 9445, 9449, 9450, 9454]
# Loaded model!! ./models/exper_immune/train_test_split_tuningFalse_filtergeneFalse/design_circuits_1_layer_immune_new_Adam_relu_5.h5
# [1, 3, 6, 8, 11, 12, 16, 17, 18, 19] [9437, 9438, 9440, 9444, 9445, 9446, 9447, 9448, 9451, 9452]
# Loaded model!! ./models/exper_immune/train_test_split_tuningFalse_filtergeneFalse/design_circuits_1_layer_immune_new_Adam_relu_6.h5
# [0, 4, 5, 6, 7, 8, 9, 11, 13, 17] [9437, 9438, 9444, 9447, 9449, 9450, 9451, 9452, 9453, 9455]
# Loaded model!! ./models/exper_immune/train_test_split_tuningFalse_filtergeneFalse/design_circuits_1_layer_immune_new_Adam_relu_7.h5
# [0, 2, 3, 5, 6, 7, 8, 11, 16, 17] [9433, 9435, 9439, 9441, 9445, 9446, 9451, 9452, 9453, 9455]
# Loaded model!! ./models/exper_immune/train_test_split_tuningFalse_filtergeneFalse/design_circuits_1_layer_immune_new_Adam_relu_8.h5
# [1, 3, 6, 7, 9, 11, 13, 18, 21, 22] [9437, 9440, 9441, 9443, 9446, 9448, 9449, 9452, 9454, 9455]
# Loaded model!! ./models/exper_immune/train_test_split_tuningFalse_filtergeneFalse/design_circuits_1_layer_immune_new_Adam_relu_9.h5
# [1, 2, 3, 5, 8, 12, 13, 14, 15, 16] [9434, 9436, 9437, 9440, 9441, 9442, 9443, 9444, 9445, 9448]
# Loaded model!! ./models/exper_immune/train_test_split_tuningFalse_filtergeneFalse/design_circuits_1_layer_immune_new_Adam_relu_10.h5
# [0, 2, 4, 5, 9, 11, 14, 15, 19, 21] [9436, 9437, 9440, 9441, 9442, 9447, 9448, 9449, 9452, 9454]
# Loaded model!! ./models/exper_immune/train_test_split_tuningFalse_filtergeneFalse/design_circuits_1_layer_immune_new_Adam_relu_11.h5
# [0, 3, 4, 6, 7, 9, 10, 13, 14, 22] [9439, 9440, 9442, 9444, 9445, 9446, 9448, 9452, 9453, 9454]
# Loaded model!! ./models/exper_immune/train_test_split_tuningFalse_filtergeneFalse/design_circuits_1_layer_immune_new_Adam_relu_12.h5
# [2, 3, 4, 6, 7, 8, 14, 16, 17, 19] [9430, 9431, 9432, 9440, 9441, 9443, 9445, 9446, 9448, 9452]
# Loaded model!! ./models/exper_immune/train_test_split_tuningFalse_filtergeneFalse/design_circuits_1_layer_immune_new_Adam_relu_13.h5
# [3, 4, 7, 8, 9, 12, 14, 15, 16, 17] [9443, 9444, 9445, 9447, 9448, 9449, 9450, 9451, 9453, 9455]
# Loaded model!! ./models/exper_immune/train_test_split_tuningFalse_filtergeneFalse/design_circuits_1_layer_immune_new_Adam_relu_14.h5
# [4, 5, 6, 7, 12, 13, 15, 18, 20, 21] [9441, 9442, 9444, 9445, 9446, 9448, 9450, 9453, 9454, 9455]
# Loaded model!! ./models/exper_immune/train_test_split_tuningFalse_filtergeneFalse/design_circuits_1_layer_immune_new_Adam_relu_15.h5
# [2, 4, 5, 9, 10, 11, 13, 17, 18, 20] [9433, 9434, 9436, 9440, 9441, 9445, 9446, 9452, 9454, 9455]
# Loaded model!! ./models/exper_immune/train_test_split_tuningFalse_filtergeneFalse/design_circuits_1_layer_immune_new_Adam_relu_16.h5
# [0, 1, 2, 8, 9, 10, 13, 14, 16, 20] [9433, 9435, 9442, 9446, 9447, 9448, 9449, 9450, 9452, 9454]
# Loaded model!! ./models/exper_immune/train_test_split_tuningFalse_filtergeneFalse/design_circuits_1_layer_immune_new_Adam_relu_17.h5
# [0, 3, 4, 5, 6, 8, 9, 10, 11, 12] [9434, 9435, 9439, 9445, 9447, 9449, 9450, 9451, 9452, 9453]
# Loaded model!! ./models/exper_immune/train_test_split_tuningFalse_filtergeneFalse/design_circuits_1_layer_immune_new_Adam_relu_18.h5
# [2, 5, 6, 9, 10, 11, 12, 13, 18, 19] [9430, 9431, 9432, 9435, 9436, 9438, 9447, 9449, 9450, 9452]
# Loaded model!! ./models/exper_immune/train_test_split_tuningFalse_filtergeneFalse/design_circuits_1_layer_immune_new_Adam_relu_19.h5
# [0, 2, 3, 6, 10, 11, 13, 15, 17, 21] [9439, 9440, 9441, 9445, 9447, 9448, 9451, 9452, 9453, 9455]
# Loaded model!! ./models/exper_immune/train_test_split_tuningFalse_filtergeneFalse/design_circuits_1_layer_immune_new_Adam_relu_20.h5
# [0, 1, 4, 5, 6, 7, 8, 10, 12, 14] [9436, 9437, 9438, 9439, 9442, 9443, 9446, 9449, 9453, 9455]
# Loaded model!! ./models/exper_immune/train_test_split_tuningFalse_filtergeneFalse/design_circuits_1_layer_immune_new_Adam_relu_21.h5
# [1, 2, 3, 6, 10, 14, 15, 17, 18, 21] [9432, 9434, 9436, 9439, 9442, 9447, 9449, 9451, 9452, 9455]
# Loaded model!! ./models/exper_immune/train_test_split_tuningFalse_filtergeneFalse/design_circuits_1_layer_immune_new_Adam_relu_22.h5
# [0, 1, 3, 5, 9, 11, 14, 15, 17, 19] [9438, 9439, 9440, 9441, 9444, 9445, 9446, 9448, 9449, 9451]
# Loaded model!! ./models/exper_immune/train_test_split_tuningFalse_filtergeneFalse/design_circuits_1_layer_immune_new_Adam_relu_23.h5
# [0, 1, 2, 5, 7, 13, 16, 17, 18, 22] [9438, 9440, 9443, 9444, 9445, 9446, 9449, 9450, 9451, 9454]
# Loaded model!! ./models/exper_immune/train_test_split_tuningFalse_filtergeneFalse/design_circuits_1_layer_immune_new_Adam_relu_24.h5
# [0, 5, 7, 10, 12, 13, 14, 17, 21, 24] [9439, 9441, 9442, 9446, 9450, 9451, 9452, 9453, 9454, 9455]
# Loaded model!! ./models/exper_immune/train_test_split_tuningFalse_filtergeneFalse/design_circuits_1_layer_immune_new_Adam_relu_25.h5
# [0, 2, 3, 5, 6, 7, 9, 15, 16, 22] [9434, 9435, 9436, 9438, 9439, 9442, 9443, 9444, 9446, 9453]
# Loaded model!! ./models/exper_immune/train_test_split_tuningFalse_filtergeneFalse/design_circuits_1_layer_immune_new_Adam_relu_26.h5
# [1, 4, 6, 7, 8, 9, 10, 11, 12, 15] [9439, 9440, 9441, 9442, 9443, 9445, 9449, 9451, 9454, 9455]
# Loaded model!! ./models/exper_immune/train_test_split_tuningFalse_filtergeneFalse/design_circuits_1_layer_immune_new_Adam_relu_27.h5
# [0, 2, 3, 6, 7, 8, 10, 11, 14, 16] [9437, 9438, 9439, 9441, 9443, 9445, 9446, 9447, 9451, 9454]
# Loaded model!! ./models/exper_immune/train_test_split_tuningFalse_filtergeneFalse/design_circuits_1_layer_immune_new_Adam_relu_28.h5
# [0, 1, 2, 4, 5, 9, 13, 14, 15, 16] [9440, 9441, 9443, 9447, 9448, 9449, 9450, 9452, 9453, 9455]
# Loaded model!! ./models/exper_immune/train_test_split_tuningFalse_filtergeneFalse/design_circuits_1_layer_immune_new_Adam_relu_29.h5
# [1, 2, 6, 10, 11, 13, 14, 16, 22, 23] [9436, 9437, 9438, 9442, 9444, 9447, 9450, 9451, 9453, 9455]
# Loaded model!! ./models/exper_immune/train_test_split_tuningFalse_filtergeneFalse/design_circuits_1_layer_immune_new_Adam_relu_30.h5
# [0, 1, 3, 4, 5, 6, 8, 9, 12, 13] [9441, 9443, 9446, 9449, 9450, 9451, 9452, 9453, 9454, 9455]
# Loaded model!! ./models/exper_immune/train_test_split_tuningFalse_filtergeneFalse/design_circuits_1_layer_immune_new_Adam_relu_31.h5
# [2, 3, 6, 7, 8, 9, 10, 13, 14, 16] [9444, 9445, 9447, 9448, 9449, 9450, 9451, 9453, 9454, 9455]
# Loaded model!! ./models/exper_immune/train_test_split_tuningFalse_filtergeneFalse/design_circuits_1_layer_immune_new_Adam_relu_32.h5
# [0, 3, 5, 6, 7, 8, 9, 12, 13, 14] [9439, 9442, 9443, 9445, 9447, 9448, 9452, 9453, 9454, 9455]
# Loaded model!! ./models/exper_immune/train_test_split_tuningFalse_filtergeneFalse/design_circuits_1_layer_immune_new_Adam_relu_33.h5
# [1, 2, 3, 6, 11, 13, 15, 16, 17, 19] [9430, 9433, 9437, 9439, 9444, 9447, 9448, 9451, 9452, 9454]
# Loaded model!! ./models/exper_immune/train_test_split_tuningFalse_filtergeneFalse/design_circuits_1_layer_immune_new_Adam_relu_34.h5
# [0, 1, 2, 3, 5, 6, 7, 8, 9, 10] [9439, 9440, 9441, 9443, 9445, 9446, 9447, 9452, 9453, 9454]
# Loaded model!! ./models/exper_immune/train_test_split_tuningFalse_filtergeneFalse/design_circuits_1_layer_immune_new_Adam_relu_35.h5
# [1, 2, 3, 4, 5, 6, 9, 10, 11, 14] [9439, 9441, 9442, 9443, 9445, 9447, 9449, 9450, 9454, 9455]
# Loaded model!! ./models/exper_immune/train_test_split_tuningFalse_filtergeneFalse/design_circuits_1_layer_immune_new_Adam_relu_36.h5
# [0, 1, 2, 4, 5, 6, 9, 11, 13, 14] [9425, 9426, 9432, 9434, 9435, 9441, 9443, 9447, 9448, 9451]
# Loaded model!! ./models/exper_immune/train_test_split_tuningFalse_filtergeneFalse/design_circuits_1_layer_immune_new_Adam_relu_37.h5
# [0, 1, 2, 3, 4, 7, 8, 9, 10, 13] [9437, 9438, 9439, 9443, 9445, 9447, 9450, 9451, 9453, 9455]
# Loaded model!! ./models/exper_immune/train_test_split_tuningFalse_filtergeneFalse/design_circuits_1_layer_immune_new_Adam_relu_38.h5
# [0, 1, 2, 4, 5, 6, 7, 9, 11, 12] [9433, 9435, 9436, 9440, 9442, 9446, 9449, 9450, 9452, 9453]
# Loaded model!! ./models/exper_immune/train_test_split_tuningFalse_filtergeneFalse/design_circuits_1_layer_immune_new_Adam_relu_39.h5
# [0, 1, 10, 14, 18, 20, 23, 24, 26, 28] [9441, 9442, 9443, 9445, 9446, 9448, 9449, 9450, 9451, 9452]
# Loaded model!! ./models/exper_immune/train_test_split_tuningFalse_filtergeneFalse/design_circuits_1_layer_immune_new_Adam_relu_40.h5
# [4, 5, 13, 17, 18, 19, 22, 23, 24, 25] [9432, 9433, 9435, 9437, 9441, 9446, 9447, 9448, 9452, 9455]
# Loaded model!! ./models/exper_immune/train_test_split_tuningFalse_filtergeneFalse/design_circuits_1_layer_immune_new_Adam_relu_41.h5
# [1, 2, 3, 11, 12, 13, 17, 18, 19, 20] [9442, 9443, 9444, 9446, 9447, 9448, 9451, 9452, 9453, 9454]
# Loaded model!! ./models/exper_immune/train_test_split_tuningFalse_filtergeneFalse/design_circuits_1_layer_immune_new_Adam_relu_42.h5
# [0, 1, 4, 9, 10, 14, 15, 16, 17, 19] [9441, 9442, 9444, 9445, 9446, 9449, 9451, 9453, 9454, 9455]
# Loaded model!! ./models/exper_immune/train_test_split_tuningFalse_filtergeneFalse/design_circuits_1_layer_immune_new_Adam_relu_43.h5
# [4, 6, 9, 14, 16, 18, 19, 20, 21, 22] [9440, 9441, 9442, 9444, 9445, 9447, 9449, 9450, 9451, 9455]
# Loaded model!! ./models/exper_immune/train_test_split_tuningFalse_filtergeneFalse/design_circuits_1_layer_immune_new_Adam_relu_44.h5
# [3, 7, 10, 12, 13, 14, 16, 17, 20, 21] [9434, 9436, 9439, 9442, 9443, 9444, 9447, 9448, 9450, 9452]
# Loaded model!! ./models/exper_immune/train_test_split_tuningFalse_filtergeneFalse/design_circuits_1_layer_immune_new_Adam_relu_45.h5
# [1, 3, 5, 7, 14, 15, 17, 19, 22, 23] [9428, 9429, 9431, 9433, 9437, 9442, 9445, 9446, 9447, 9451]
# Loaded model!! ./models/exper_immune/train_test_split_tuningFalse_filtergeneFalse/design_circuits_1_layer_immune_new_Adam_relu_46.h5
# [1, 4, 7, 8, 10, 13, 14, 16, 18, 19] [9437, 9438, 9439, 9444, 9446, 9447, 9449, 9451, 9453, 9455]
# Loaded model!! ./models/exper_immune/train_test_split_tuningFalse_filtergeneFalse/design_circuits_1_layer_immune_new_Adam_relu_47.h5
# [3, 8, 9, 11, 12, 14, 15, 18, 19, 20] [9435, 9437, 9438, 9440, 9441, 9443, 9448, 9451, 9452, 9455]
# Loaded model!! ./models/exper_immune/train_test_split_tuningFalse_filtergeneFalse/design_circuits_1_layer_immune_new_Adam_relu_48.h5
# [1, 3, 4, 8, 13, 14, 16, 21, 27, 29] [9418, 9419, 9424, 9426, 9433, 9436, 9444, 9450, 9451, 9452]
# Loaded model!! ./models/exper_immune/train_test_split_tuningFalse_filtergeneFalse/design_circuits_1_layer_immune_new_Adam_relu_49.h5
# [1, 9, 12, 14, 19, 20, 21, 22, 29, 30] [9438, 9439, 9441, 9442, 9444, 9445, 9446, 9447, 9453, 9455]
# Loaded model!! ./models/exper_immune/train_test_split_tuningFalse_filtergeneFalse/design_circuits_1_layer_immune_new_Adam_relu_50.h5
# [2, 6, 8, 13, 14, 16, 17, 19, 22, 25] [9443, 9447, 9448, 9449, 9450, 9451, 9452, 9453, 9454, 9455]
# Loaded model!! ./models/exper_immune/train_test_split_tuningFalse_filtergeneFalse/design_circuits_1_layer_immune_new_Adam_relu_51.h5
# [1, 4, 8, 10, 13, 17, 18, 20, 24, 25] [9436, 9439, 9442, 9443, 9444, 9445, 9447, 9449, 9450, 9451]
# Loaded model!! ./models/exper_immune/train_test_split_tuningFalse_filtergeneFalse/design_circuits_1_layer_immune_new_Adam_relu_52.h5
# [2, 3, 5, 6, 7, 8, 12, 13, 14, 15] [9428, 9429, 9430, 9433, 9434, 9436, 9438, 9440, 9446, 9454]
# Loaded model!! ./models/exper_immune/train_test_split_tuningFalse_filtergeneFalse/design_circuits_1_layer_immune_new_Adam_relu_53.h5
# [0, 1, 2, 3, 5, 6, 8, 9, 13, 15] [9438, 9440, 9443, 9444, 9445, 9449, 9450, 9451, 9454, 9455]
# Loaded model!! ./models/exper_immune/train_test_split_tuningFalse_filtergeneFalse/design_circuits_1_layer_immune_new_Adam_relu_54.h5
# [1, 2, 6, 9, 11, 12, 15, 18, 21, 23] [9437, 9438, 9440, 9441, 9443, 9444, 9447, 9450, 9453, 9455]
# Loaded model!! ./models/exper_immune/train_test_split_tuningFalse_filtergeneFalse/design_circuits_1_layer_immune_new_Adam_relu_55.h5
# [2, 4, 5, 11, 12, 17, 18, 20, 26, 27] [9435, 9437, 9439, 9440, 9441, 9443, 9444, 9449, 9452, 9455]
# Loaded model!! ./models/exper_immune/train_test_split_tuningFalse_filtergeneFalse/design_circuits_1_layer_immune_new_Adam_relu_56.h5
# [5, 6, 9, 10, 12, 13, 14, 15, 16, 18] [9432, 9436, 9437, 9438, 9439, 9445, 9446, 9447, 9448, 9454]
# Loaded model!! ./models/exper_immune/train_test_split_tuningFalse_filtergeneFalse/design_circuits_1_layer_immune_new_Adam_relu_57.h5
# [2, 3, 5, 6, 7, 14, 15, 19, 20, 21] [9438, 9441, 9443, 9446, 9447, 9449, 9450, 9451, 9454, 9455]
# Loaded model!! ./models/exper_immune/train_test_split_tuningFalse_filtergeneFalse/design_circuits_1_layer_immune_new_Adam_relu_58.h5
# [1, 2, 4, 5, 6, 7, 9, 11, 12, 13] [9437, 9438, 9439, 9440, 9442, 9448, 9449, 9452, 9453, 9455]
# Loaded model!! ./models/exper_immune/train_test_split_tuningFalse_filtergeneFalse/design_circuits_1_layer_immune_new_Adam_relu_59.h5
# [0, 3, 10, 11, 12, 15, 18, 19, 22, 24] [9438, 9442, 9443, 9447, 9448, 9450, 9452, 9453, 9454, 9455]
# Loaded model!! ./models/exper_immune/train_test_split_tuningFalse_filtergeneFalse/design_circuits_1_layer_immune_new_Adam_relu_60.h5
# [0, 2, 4, 7, 8, 9, 10, 12, 13, 14] [9440, 9442, 9443, 9444, 9447, 9449, 9450, 9451, 9452, 9453]
# Loaded model!! ./models/exper_immune/train_test_split_tuningFalse_filtergeneFalse/design_circuits_1_layer_immune_new_Adam_relu_61.h5
# [1, 2, 3, 4, 5, 7, 8, 9, 10, 11] [9435, 9439, 9443, 9444, 9446, 9448, 9450, 9452, 9453, 9455]
# Loaded model!! ./models/exper_immune/train_test_split_tuningFalse_filtergeneFalse/design_circuits_1_layer_immune_new_Adam_relu_62.h5
# [0, 2, 3, 8, 10, 12, 17, 18, 20, 21] [9435, 9439, 9440, 9445, 9447, 9448, 9449, 9451, 9453, 9454]
# Loaded model!! ./models/exper_immune/train_test_split_tuningFalse_filtergeneFalse/design_circuits_1_layer_immune_new_Adam_relu_63.h5
# [0, 1, 2, 3, 4, 6, 8, 10, 11, 12] [9437, 9439, 9443, 9444, 9445, 9446, 9450, 9453, 9454, 9455]
# Loaded model!! ./models/exper_immune/train_test_split_tuningFalse_filtergeneFalse/design_circuits_1_layer_immune_new_Adam_relu_64.h5
# [0, 1, 2, 3, 4, 5, 7, 9, 11, 12] [9438, 9439, 9440, 9441, 9445, 9446, 9447, 9450, 9451, 9454]
# Loaded model!! ./models/exper_immune/train_test_split_tuningFalse_filtergeneFalse/design_circuits_1_layer_immune_new_Adam_relu_65.h5
# [0, 2, 3, 4, 5, 6, 8, 10, 11, 14] [9442, 9443, 9444, 9447, 9448, 9449, 9450, 9451, 9452, 9454]
# Loaded model!! ./models/exper_immune/train_test_split_tuningFalse_filtergeneFalse/design_circuits_1_layer_immune_new_Adam_relu_66.h5
# [0, 1, 2, 3, 4, 7, 8, 12, 13, 15] [9434, 9436, 9437, 9440, 9441, 9442, 9445, 9446, 9448, 9450]
# Loaded model!! ./models/exper_immune/train_test_split_tuningFalse_filtergeneFalse/design_circuits_1_layer_immune_new_Adam_relu_67.h5
# [0, 2, 4, 6, 12, 13, 15, 17, 18, 20] [9435, 9436, 9440, 9443, 9444, 9445, 9447, 9449, 9452, 9455]
# Loaded model!! ./models/exper_immune/train_test_split_tuningFalse_filtergeneFalse/design_circuits_1_layer_immune_new_Adam_relu_68.h5
# [0, 4, 5, 6, 7, 10, 15, 18, 19, 21] [9442, 9443, 9444, 9445, 9446, 9447, 9448, 9449, 9450, 9452]
# Loaded model!! ./models/exper_immune/train_test_split_tuningFalse_filtergeneFalse/design_circuits_1_layer_immune_new_Adam_relu_69.h5
# [1, 2, 3, 4, 11, 12, 14, 17, 18, 20] [9439, 9440, 9443, 9444, 9447, 9448, 9449, 9451, 9453, 9454]
# Loaded model!! ./models/exper_immune/train_test_split_tuningFalse_filtergeneFalse/design_circuits_1_layer_immune_new_Adam_relu_70.h5
# [0, 1, 7, 8, 10, 11, 14, 17, 20, 21] [9434, 9435, 9436, 9437, 9438, 9439, 9440, 9441, 9442, 9444]
# Loaded model!! ./models/exper_immune/train_test_split_tuningFalse_filtergeneFalse/design_circuits_1_layer_immune_new_Adam_relu_71.h5
# [2, 3, 4, 8, 10, 11, 15, 16, 17, 20] [9425, 9428, 9434, 9436, 9437, 9440, 9443, 9444, 9449, 9450]
# Loaded model!! ./models/exper_immune/train_test_split_tuningFalse_filtergeneFalse/design_circuits_1_layer_immune_new_Adam_relu_72.h5
# [3, 4, 6, 7, 8, 11, 12, 14, 15, 16] [9444, 9446, 9447, 9448, 9449, 9450, 9452, 9453, 9454, 9455]
# Loaded model!! ./models/exper_immune/train_test_split_tuningFalse_filtergeneFalse/design_circuits_1_layer_immune_new_Adam_relu_73.h5
# [0, 1, 2, 4, 7, 8, 9, 11, 13, 14] [9434, 9437, 9438, 9439, 9444, 9446, 9448, 9449, 9451, 9452]
# Loaded model!! ./models/exper_immune/train_test_split_tuningFalse_filtergeneFalse/design_circuits_1_layer_immune_new_Adam_relu_74.h5
# [1, 2, 3, 5, 6, 7, 8, 9, 10, 12] [9440, 9441, 9442, 9445, 9447, 9449, 9450, 9451, 9452, 9454]
# Loaded model!! ./models/exper_immune/train_test_split_tuningFalse_filtergeneFalse/design_circuits_1_layer_immune_new_Adam_relu_75.h5
# [1, 2, 3, 6, 10, 11, 12, 13, 14, 15] [9437, 9439, 9440, 9441, 9442, 9443, 9448, 9449, 9454, 9455]
# Loaded model!! ./models/exper_immune/train_test_split_tuningFalse_filtergeneFalse/design_circuits_1_layer_immune_new_Adam_relu_76.h5
# [0, 1, 2, 3, 5, 6, 8, 9, 10, 11] [9437, 9440, 9442, 9443, 9445, 9446, 9448, 9451, 9452, 9455]
# Loaded model!! ./models/exper_immune/train_test_split_tuningFalse_filtergeneFalse/design_circuits_1_layer_immune_new_Adam_relu_77.h5
# [0, 1, 3, 6, 8, 9, 12, 14, 17, 25] [9437, 9441, 9442, 9444, 9445, 9448, 9449, 9450, 9453, 9455]
# Loaded model!! ./models/exper_immune/train_test_split_tuningFalse_filtergeneFalse/design_circuits_1_layer_immune_new_Adam_relu_78.h5
# [0, 2, 5, 7, 8, 10, 12, 14, 24, 27] [9440, 9441, 9442, 9443, 9444, 9445, 9448, 9451, 9454, 9455]
# Loaded model!! ./models/exper_immune/train_test_split_tuningFalse_filtergeneFalse/design_circuits_1_layer_immune_new_Adam_relu_79.h5
# [0, 2, 5, 9, 12, 13, 14, 15, 17, 21] [9443, 9444, 9445, 9446, 9448, 9449, 9450, 9451, 9453, 9454]
# Loaded model!! ./models/exper_immune/train_test_split_tuningFalse_filtergeneFalse/design_circuits_1_layer_immune_new_Adam_relu_80.h5
# [0, 1, 5, 7, 8, 9, 10, 11, 12, 14] [9441, 9443, 9445, 9446, 9447, 9448, 9451, 9452, 9453, 9455]
# Loaded model!! ./models/exper_immune/train_test_split_tuningFalse_filtergeneFalse/design_circuits_1_layer_immune_new_Adam_relu_81.h5
# [0, 1, 2, 3, 5, 8, 9, 12, 13, 15] [9439, 9440, 9441, 9442, 9445, 9446, 9450, 9451, 9453, 9454]
# Loaded model!! ./models/exper_immune/train_test_split_tuningFalse_filtergeneFalse/design_circuits_1_layer_immune_new_Adam_relu_82.h5
# [4, 5, 6, 7, 8, 9, 10, 12, 14, 17] [9435, 9437, 9438, 9439, 9441, 9446, 9447, 9451, 9452, 9453]
# Loaded model!! ./models/exper_immune/train_test_split_tuningFalse_filtergeneFalse/design_circuits_1_layer_immune_new_Adam_relu_83.h5
# [0, 1, 3, 5, 7, 10, 13, 16, 17, 18] [9439, 9440, 9442, 9444, 9446, 9447, 9450, 9452, 9454, 9455]
# Loaded model!! ./models/exper_immune/train_test_split_tuningFalse_filtergeneFalse/design_circuits_1_layer_immune_new_Adam_relu_84.h5
# [0, 2, 5, 7, 8, 11, 12, 13, 14, 20] [9430, 9431, 9438, 9439, 9440, 9442, 9446, 9449, 9450, 9452]
# Loaded model!! ./models/exper_immune/train_test_split_tuningFalse_filtergeneFalse/design_circuits_1_layer_immune_new_Adam_relu_85.h5
# [0, 2, 3, 4, 6, 10, 14, 17, 18, 19] [9442, 9443, 9444, 9445, 9447, 9448, 9449, 9450, 9451, 9453]
# Loaded model!! ./models/exper_immune/train_test_split_tuningFalse_filtergeneFalse/design_circuits_1_layer_immune_new_Adam_relu_86.h5
# [4, 6, 8, 9, 10, 14, 15, 16, 19, 20] [9440, 9444, 9445, 9446, 9447, 9449, 9450, 9451, 9453, 9455]
# Loaded model!! ./models/exper_immune/train_test_split_tuningFalse_filtergeneFalse/design_circuits_1_layer_immune_new_Adam_relu_87.h5
# [0, 2, 3, 4, 6, 9, 12, 14, 15, 21] [9438, 9440, 9442, 9444, 9445, 9446, 9451, 9452, 9454, 9455]
# Loaded model!! ./models/exper_immune/train_test_split_tuningFalse_filtergeneFalse/design_circuits_1_layer_immune_new_Adam_relu_88.h5
# [0, 1, 2, 3, 4, 5, 7, 8, 9, 10] [9440, 9441, 9442, 9444, 9445, 9448, 9452, 9453, 9454, 9455]
# Loaded model!! ./models/exper_immune/train_test_split_tuningFalse_filtergeneFalse/design_circuits_1_layer_immune_new_Adam_relu_89.h5
# [0, 4, 6, 7, 11, 12, 14, 16, 17, 18] [9433, 9435, 9440, 9441, 9443, 9445, 9446, 9450, 9452, 9453]
# Loaded model!! ./models/exper_immune/train_test_split_tuningFalse_filtergeneFalse/design_circuits_1_layer_immune_new_Adam_relu_90.h5
# [0, 2, 4, 6, 11, 14, 16, 17, 21, 22] [9441, 9442, 9443, 9444, 9448, 9449, 9450, 9452, 9454, 9455]
# Loaded model!! ./models/exper_immune/train_test_split_tuningFalse_filtergeneFalse/design_circuits_1_layer_immune_new_Adam_relu_91.h5
# [0, 3, 5, 7, 8, 9, 10, 11, 12, 18] [9442, 9443, 9445, 9446, 9448, 9449, 9450, 9452, 9453, 9454]
# Loaded model!! ./models/exper_immune/train_test_split_tuningFalse_filtergeneFalse/design_circuits_1_layer_immune_new_Adam_relu_92.h5
# [2, 3, 5, 6, 8, 9, 10, 12, 15, 17] [9432, 9435, 9436, 9438, 9440, 9445, 9447, 9449, 9451, 9453]
# Loaded model!! ./models/exper_immune/train_test_split_tuningFalse_filtergeneFalse/design_circuits_1_layer_immune_new_Adam_relu_93.h5
# [0, 2, 3, 4, 6, 7, 8, 9, 10, 11] [9436, 9437, 9438, 9439, 9441, 9443, 9444, 9447, 9448, 9449]
# Loaded model!! ./models/exper_immune/train_test_split_tuningFalse_filtergeneFalse/design_circuits_1_layer_immune_new_Adam_relu_94.h5
# [5, 8, 10, 11, 14, 15, 22, 24, 27, 28] [9442, 9443, 9444, 9445, 9446, 9449, 9450, 9452, 9453, 9455]
# Loaded model!! ./models/exper_immune/train_test_split_tuningFalse_filtergeneFalse/design_circuits_1_layer_immune_new_Adam_relu_95.h5
# [0, 1, 2, 4, 6, 9, 10, 12, 15, 16] [9431, 9433, 9437, 9439, 9441, 9442, 9448, 9451, 9452, 9453]
# Loaded model!! ./models/exper_immune/train_test_split_tuningFalse_filtergeneFalse/design_circuits_1_layer_immune_new_Adam_relu_96.h5
# [0, 1, 2, 3, 6, 10, 14, 15, 16, 18] [9437, 9440, 9441, 9442, 9448, 9449, 9450, 9452, 9453, 9455]
# Loaded model!! ./models/exper_immune/train_test_split_tuningFalse_filtergeneFalse/design_circuits_1_layer_immune_new_Adam_relu_97.h5
# [0, 1, 5, 7, 8, 10, 13, 14, 15, 19] [9434, 9436, 9437, 9438, 9440, 9441, 9444, 9445, 9446, 9447]
# Loaded model!! ./models/exper_immune/train_test_split_tuningFalse_filtergeneFalse/design_circuits_1_layer_immune_new_Adam_relu_98.h5
# [2, 4, 5, 7, 9, 10, 15, 16, 20, 21] [9432, 9434, 9435, 9439, 9442, 9443, 9446, 9447, 9454, 9455]
# Loaded model!! ./models/exper_immune/train_test_split_tuningFalse_filtergeneFalse/design_circuits_1_layer_immune_new_Adam_relu_99.h5
